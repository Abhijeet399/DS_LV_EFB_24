# %%
path='housing.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
boston= pd.read_csv(path)

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston = pd.read_csv(path, header=None, delimiter=r'\s+',names=column_names)

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
label=boston['MEDV']

# %%
label
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
dataset=boston.drop('MEDV', axis=1)

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
# pd.read_csv?

# %%
# dividing the data into training and testing 

# training set on that we are to train the model and this constitutes the majority of our data around 70 percent
# testing set pe hum model ko test karte hai and this is about 20 percent of the total data
# validation set is used to test the model in between the training  and this about 10 percent

# %%
# overfitting is when the model works incredibly well on the training data , but very poorly on the testing data

# %%
# how to divide

# %%
# dataset=pd.DataFrame(boston['CRIM'],boston['ZN'],boston['INDUS'],boston['CHAS'],columns=['CRIM', 'ZN', 'INDUS', 'CHAS'])

# %%
# pd.DataFrame?

# %%
# normalization 

# we are reducing the upper and lower limit of our data to 0 and 1, to not encounter any issues while it is running

# %%
dataset.shape
# Out:
# (506, 13)

# %%
X_train=dataset[:406]
X_test=dataset[406:]
Y_train=label[:406]
Y_test=label[406:]    #the data is now divided between training and testing sets

# %%
X_train, X_test
# Out:
# (         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
#  0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
#  1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
#  2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
#  3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
#  4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
#  ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
#  401  14.23620   0.0  18.10     0  0.693  6.343  100.0  1.5741   24  666.0
#  402   9.59571   0.0  18.10     0  0.693  6.404  100.0  1.6390   24  666.0
#  403  24.80170   0.0  18.10     0  0.693  5.349   96.0  1.7028   24  666.0
#  404  41.52920   0.0  18.10     0  0.693  5.531   85.4  1.6074   24  666.0
#  405  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666.0
#
#       PTRATIO       B  LSTAT
#  0       15.3  396.90   4.98
# ...

# %%
Y_test, Y_train
# Out:
# (406    11.9
#  407    27.9
#  408    17.2
#  409    27.5
#  410    15.0
#         ...
#  501    22.4
#  502    20.6
#  503    23.9
#  504    22.0
#  505    11.9
#  Name: MEDV, Length: 100, dtype: float64,
#  0      24.0
#  1      21.6
#  2      34.7
#  3      33.4
#  4      36.2
#         ...
#  401     7.2
#  402    12.1
#  403     8.3
#  404     8.5
#  405     5.0
#  Name: MEDV, Length: 406, dtype: float64)

# %%
#normalization, mean and the standard deviation

# %%
u = np.mean(dataset,axis=0)
std=np.std(dataset,axis=0)

# %%
u.shape, std.shape
# Out:
# ((13,), (13,))

# %%
X_train=((X_train - u)/std)
X_test = ((X_test - u)/std)

# %%
X_train = np.array(X_train)
X_test=np.array(X_test)

# %%
X_train, X_test
# Out:
# (array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#           0.44105193, -1.0755623 ],
#         [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#           0.44105193, -0.49243937],
#         [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#           0.39642699, -1.2087274 ],
#         ...,
#         [ 2.46573659, -0.48772236,  1.01599907, ...,  0.80657583,
#           0.44105193,  0.99760795],
#         [ 4.41236983, -0.48772236,  1.01599907, ...,  0.80657583,
#          -0.2983844 ,  2.06433044],
#         [ 7.48364564, -0.48772236,  1.01599907, ...,  0.80657583,
#           0.31024714,  1.4475658 ]]),
#  array([[ 1.99029374, -0.48772236,  1.01599907, ...,  0.80657583,
#           0.14852285,  1.49802836],
#         [ 0.97027072, -0.48772236,  1.01599907, ...,  0.80657583,
#          -0.26954813, -0.07331975],
#         [ 0.4410972 , -0.48772236,  1.01599907, ...,  0.80657583,
#          -0.46087619,  1.92696014],
#         ...,
# ...

# %%
X_train= X_train[:,:4]
X_test= X_test[:,:4]

# %%
X_train, X_test
# Out:
# (array([[-0.41978194,  0.28482986, -1.2879095 , -0.27259857],
#         [-0.41733926, -0.48772236, -0.59338101, -0.27259857],
#         [-0.41734159, -0.48772236, -0.59338101, -0.27259857],
#         ...,
#         [ 2.46573659, -0.48772236,  1.01599907, -0.27259857],
#         [ 4.41236983, -0.48772236,  1.01599907, -0.27259857],
#         [ 7.48364564, -0.48772236,  1.01599907, -0.27259857]]),
#  array([[ 1.99029374e+00, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
#         [ 9.70270723e-01, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
#         [ 4.41097196e-01, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
#         [ 1.25971423e+00, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
#         [ 5.53032093e+00, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
#         [ 1.21460796e+00, -4.87722365e-01,  1.01599907e+00,
#          -2.72598567e-01],
# ...

# %%
plt.scatter(X_train[:,1], Y_train)
plt.show()

# %%
# X_train[:,3].shape,Y_train.shape

# %%
ones=np.ones((X_train.shape[0],1))

ones.shape

X_train=np.hstack((ones,X_train))

# %%
X_train
# Out:
# array([[ 1.        , -0.41978194,  0.28482986, -1.2879095 , -0.27259857],
#        [ 1.        , -0.41733926, -0.48772236, -0.59338101, -0.27259857],
#        [ 1.        , -0.41734159, -0.48772236, -0.59338101, -0.27259857],
#        ...,
#        [ 1.        ,  2.46573659, -0.48772236,  1.01599907, -0.27259857],
#        [ 1.        ,  4.41236983, -0.48772236,  1.01599907, -0.27259857],
#        [ 1.        ,  7.48364564, -0.48772236,  1.01599907, -0.27259857]])

# %%
# linear regression formula for y = thetha0 + thetha1*x1 + thetha2 * x2 ....

# %%
def hypothesis(X,theta):   #x was small , it should have been capital 
    y_=0
    n=X.shape[0]

    for i in range(n):
        y_+=theta[i]*X[i]

    return y_

# %%
def cost(X,Y,theta):
    m=X.shape[0]
    total_error=0

    for i in range(m):
        y_p=hypothesis(X[i],theta)

        total_error+= (y_p - Y[i])**2

    return total_error/m

# %%
def gradient(X,Y,theta):
    m,n = X.shape   #should bw x.shape as well

    grad= np.zeros((n,))

    for j in range(n):
        for i in range(m):
            x=X[i]
            y_p=hypothesis(X[i],theta)
            y_t=Y[i]

            grad[j]+= (y_p-y_t)*x[j]
    return grad/m

# %%
def gradient_descent(X, Y , learning_rate=0.001, max_steps=2000):
    m,n = X.shape       #changed from shape[0] as the answer needs to be 2d as well to accomdate 2 variables rather than 1d
    theta= np.zeros((n,))
    cost_epoch=[]

    for i in range(max_steps):
        grad=gradient(X,Y, theta)
        e=cost(X,Y, theta)
        cost_epoch.append(e)

        for j in range(n):
            theta[j]=theta[j]-learning_rate*grad[j]

    return theta, cost_epoch

# %%
theta, cost_epoch= gradient_descent(X_train, Y_train ,learning_rate=0.1 ,max_steps=200)

# %%
X_train.shape[0]
# Out:
# 406

# %%
theta
# Out:
# array([22.84116463, -2.12544852,  1.3876623 , -2.65504672,  1.63380132])

# %%
cost_epoch
# Out:
# [666.9598768472904,
#  526.956079967837,
#  422.807968055955,
#  344.52789283740276,
#  285.0976595220886,
#  239.54400888677966,
#  204.31091716733928,
#  176.83151528238568,
#  155.23466173993123,
#  138.14266138967494,
#  124.53092547543064,
#  113.62991714116914,
#  104.85611239120092,
#  97.76298591095104,
#  92.00590578014727,
#  87.31675741115195,
#  83.48542544077866,
#  80.34614962497177,
#  77.76737503791328,
#  75.64413029503726,
#  73.89225186479742,
#  72.44396925484736,
#  71.2445028410043,
#  70.24942216911217,
#  69.42258044062584,
#  68.73448925076711,
#  68.16103239332608,
#  67.68244273203531,
#  67.28248456017776,
#  66.9477974668422,
#  66.66736785408808,
#  66.432101856464,
#  66.23447917760106,
#  66.06827175994245,
#  65.92831459022074,
#  65.81031856724935,
#  65.71071740476273,
#  65.62654214702532,
#  65.55531814058716,
#  65.49498030844255,
#  65.44380337097495,
#  65.40034429572916,
#  65.36339476930316,
#  65.33194189585868,
#  65.30513565843036,
# ...

# %%
plt.plot(cost_epoch)
plt.show()

# %%
ones=np.ones((X_test.shape[0],1))

ones.shape

X_test=np.hstack((ones,X_test))

# %%
X_test
# Out:
# array([[ 1.00000000e+00,  1.99029374e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  9.70270723e-01, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  4.41097196e-01, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  1.25971423e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  5.53032093e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  1.21460796e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  1.76857946e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  2.91425066e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
#        [ 1.00000000e+00,  4.90310412e+00, -4.87722365e-01,
#          1.01599907e+00, -2.72598567e-01],
# ...

# %%
y_pred=[]

for i in range(X_test.shape[0]):
    pred=hypothesis(X_test[i],theta)
    y_pred.append(pred)

# %%
y_pred=np.array(y_pred)

# %%
y_pred
# Out:
# array([14.79120689, 16.95921332, 18.08394441, 16.34401605,  7.26706133,
#        16.43988709, 15.26244919, 12.82738403,  8.60017838, 15.44212083,
#        17.2354733 , 13.49897603,  1.72694675, 16.99354485, 17.17284547,
#        18.17825718, 16.93519609, 18.17137356, 17.74057222, 15.99229101,
#        16.88597437, 10.59976738, 18.09304177, 17.60533122, 17.81477334,
#        17.42639915, 18.32135634, 18.5348104 , 16.47384761, 17.15478926,
#        16.34834459, 16.1612526 , 16.53204796, 17.59253358, 14.46102563,
#        17.51003155, 18.51371184, 17.45008494, 16.74867299, 17.27564218,
#        18.35993726, 17.46039676, 17.60775521, 18.0537386 , 18.25366535,
#        18.56942143, 18.65623221, 17.8751355 , 17.5621101 , 18.73978546,
#        18.76044869, 17.88688687, 17.99778414, 18.23302438, 18.72500411,
#        19.00178846, 18.26919863, 18.47542774, 17.97624284, 19.13276028,
#        18.9815383 , 18.82143168, 16.06268549, 16.68119718, 18.83960908,
# ...

# %%
Y_test=np.array(Y_test)

# %%
for i in range(len(y_pred)):
    print(y_pred[i],Y_test[i])
# Out:
# 14.791206893053445 11.9
# 16.95921331822616 27.9
# 18.08394441046807 17.2
# 16.344016049434067 27.5
# 7.267061332685206 15.0
# 16.43988709373441 17.2
# 15.262449188205704 17.9
# 12.827384025852707 16.3
# 8.60017837980998 7.0
# 15.442120825408413 7.2
# 17.235473301144253 7.5
# 13.498976026586174 10.4
# 1.726946751796702 8.8
# 16.993544848022047 8.4
# 17.17284546725146 16.7
# 18.17825717928056 14.2
# 16.935196088087967 20.8
# 18.171373559149295 13.4
# 17.740572223086577 11.7
# 15.992291010747044 8.3
# 16.885974370297024 10.2
# 10.5997673796367 10.9
# 18.09304177117335 11.0
# 17.60533122491295 9.5
# 17.814773344293133 14.5
# 17.426399150203682 14.1
# 18.321356338128652 16.1
# 18.53481039852677 14.3
# 16.473847605557005 11.7
# 17.154789259217598 13.4
# 16.34834459245588 9.6
# 16.161252595787204 8.7
# 16.532047958301767 8.4
# 17.592533578287306 12.8
# 14.461025631349298 10.5
# 17.510031548291487 17.1
# 18.51371184311186 18.4
# 17.45008493761906 15.4
# 16.748672985645012 10.8
# ...
